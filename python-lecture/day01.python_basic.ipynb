# %%
"hello python"
# Out:
# 'hello python'

# %%
1 + 1
# Out:
# 2

# %%
1 - 7
# Out:
# -6

# %%
25 / 5
# Out:
# 5.0

# %%
type(2 + 1)
# Out:
# int

# %%
type(25 / 5)
# Out:
# float

# %%
15 // 5
# Out:
# 3

# %%
7 / 3
# Out:
# 2.3333333333333335

# %%
7 // 3
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %%
2 ** 10
# Out:
# 1024

# %%
2 == 3
# Out:
# False

# %%
2 == 2
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
3 < 7
# Out:
# True

# %%
type("a") == str
# Out:
# True

# %%
3 <= 3
# Out:
# True

# %%
17 >= 25
# Out:
# False

# %%
3 <= 1 #등호가 먼저 나오면 a = 1처럼 선언하는 것으로 착각하여 문법 오류가 난다
# Out:
# False

# %%
## 변수: 정해지지 않는 값이 있는 위치, 또는 공간

# %%
fast = 10

# %%
campus = 2.0

# %%
"fastcampus"
# Out:
# 'fastcampus'

# %%
fast / campus
# Out:
# 5.0

# %%
fast ** campus
# Out:
# 100.0

# %%
a = "fast"
b = "campus"

# %%
a + b
# Out:
# 'fastcampus'

# %%
a = 'fast'
b = 'campus'

# %%
a + b
# Out:
# 'fastcampus'

# %%
i = 10
r = 100
v = i * r
v
# Out:
# 1000

# %%
r = 10
pi = 3.1415
4 / 3 * pi * (r ** 3)
# Out:
# 4188.666666666666

# %%
a + b
# Out:
# 'fastcampus'

# %%
def print_(num):
    return num + 1

print_(1)
# Out:
# 2

# %%
# 클래스 이름은 NewCamelCase
# 변수,함수,메소드 이름은 new_snake_case, 그리고 가급적 풀어쓰지 말 것!

yi_yong_jin = "awesome"
print(yi_yong_jin)
# Out:
# awesome

# %%
"python" , 5
# Out:
# ('python', 5)

# %%
int_ = 7
float_ = 3.7000001
str_ = "6"
bool_ = True
list_ = [1,2,3]

# %%
int(float_)  # 실수형을 정수로 변경하면 소수점 아래를 버린다
# Out:
# 3

# %%
float(int_)
# Out:
# 7.0

# %%
print(int(str_))
int(str_) == 6
# Out:
# 6
# True

# %%
float(str_)
# Out:
# 6.0

# %%
str(int_)
# Out:
# '7'

# %%
name = input("What is your name? ")
print("Hi," , name)
# Out:
# What is your name? yongjin
# Hi, yongjin

# %%
type(name)
# Out:
# str

# %%
name = input("What is your name? ") # input함수는 사용자가 입력한 내용은 숫자든 실수든 문자든 모두 str로 입력받음
print("Hi," , name)
type(name)
# Out:
# What is your name? yongjin
# Hi, yongjin
# str

# %%
name = int(input("What is your name? ")) # input함수는 사용자가 입력한 내용은 숫자든 실수든 문자든 모두 str로 입력받음
print("Hi," , name)
type(name)
# Out:
# What is your name? 123132
# Hi, 123132
# int

# %%
name = eval(input("What is your name? ")) # eval함수는 입력값을 분석해서 타입을 만듬, 문제는 문자열은 ""사이에 넣어져야만 문자열로 인식
print("Hi," , name)
type(name)
# Out:
# What is your name? 34343
# Hi, 34343
# int

# %%
name = eval(input("What is your name? ")) # eval함수 문제는 문자열은 ""사이에 넣어져야만 문자열로 인식
print("Hi," , name)
type(name)
# Out:
# What is your name? 34234234
# Hi, 34234234
# int
